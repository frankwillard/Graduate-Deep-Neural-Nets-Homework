# %% [markdown]
# ### Lab2 (a) Model preperation

# %%
from resnet20 import ResNetCIFAR
from train_util import train, finetune, test
import torch
import numpy as np

import time

import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
import torch.optim as optim

from FP_layers import *

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
net = ResNetCIFAR(num_layers=20, Nbits=None)
net = net.to(device)

# %%
# Load the best weight paramters
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=0.3231, Test accuracy=0.9151

# %% [markdown]
# ### Lab2 (b) Prune by percentage

# %%
def prune_by_percentage(layer, q=80.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least 
    significant weight parameters will be pruned.
    """    
    # Convert the weight of "layer" to numpy array
    np_weight = np.array(layer.weight.data.cpu())
    
    # Compute the q-th percentile of the abs of the converted array
    q_percentile = np.percentile(np.absolute(np_weight), q)
    
    # Generate a binary mask same shape as weight to decide which element to prune
    bin_mask = np.where(np.absolute(np_weight) >= q_percentile, 1, 0)
        
    # Convert mask to torch tensor and put on GPU
    bin_mask = torch.from_numpy(bin_mask).to(device)
    
    # Multiply the weight by mask to perform pruning
    layer.weight.data = layer.weight.data * bin_mask
    
    return layer.weight.data

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # change q value
        prune_by_percentage(layer, q=80.0)
        
        # Optional: Check the sparsity you achieve in each layer
        # Convert the weight of "layer" to numpy array
        np_weight = np.array(layer.weight.data.cpu())
        # Count number of zeros
        zeros = np.count_nonzero(np_weight==0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.4.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.4.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.5.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.5.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=6.3138, Test accuracy=0.1003

# %% [markdown]
# ### Lab2 (c) Finetune pruned model

# %%
def finetune_after_prune(net, trainloader, criterion, optimizer, prune=True):
    """
    Finetune the pruned model for a single epoch
    Make sure pruned weights are kept as zero
    """
    # Build a dictionary for the nonzero weights
    weight_mask = {}
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Your code here: generate a mask in GPU torch tensor to have 1 for nonzero element and 0 for zero element 
            bin_mask = np.where(np.array(layer.weight.data.cpu()) == 0, 0, 1)
            weight_mask[name] = torch.from_numpy(bin_mask).to(device)
    
    global_steps = 0
    train_loss = 0
    correct = 0
    total = 0
    start = time.time()
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        if prune:
            for name,layer in net.named_modules():
                if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                    # Your code here: Use weight_mask to make sure zero elements remains zero
                    sparser_weights = layer.weight.data * weight_mask[name]
                    layer.weight.data = sparser_weights.float().to(device)
        
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        global_steps += 1

        if global_steps % 50 == 0:
            end = time.time()
            batch_size = 256
            num_examples_per_second = 50 * batch_size / (end - start)
            print("[Step=%d]\tLoss=%.4f\tacc=%.4f\t%.1f examples/second"
                 % (global_steps, train_loss / (batch_idx + 1), (correct / total), num_examples_per_second))
            start = time.time()

# %%
# Get pruned model
net.load_state_dict(torch.load("pretrained_model.pt"))
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        prune_by_percentage(layer, q=80.0)

# Training setup, do not change
batch_size=256
lr=0.002
reg=1e-4

print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=16)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.875, weight_decay=reg, nesterov=False)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Model finetuning
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    net.train()
    finetune_after_prune(net, trainloader, criterion, optimizer)
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))

    if val_acc > best_acc:
        best_acc = val_acc
        print("Saving...")
        torch.save(net.state_dict(), "net_after_finetune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.9619	acc=0.6903	4743.8 examples/second
# [Step=100]	Loss=0.8004	acc=0.7400	5488.7 examples/second
# [Step=150]	Loss=0.7214	acc=0.7627	5399.9 examples/second
# Test Loss=0.5548, Test acc=0.8191
# Saving...
#
# Epoch: 1
# [Step=50]	Loss=0.4708	acc=0.8410	4230.1 examples/second
# [Step=100]	Loss=0.4610	acc=0.8438	5047.1 examples/second
# [Step=150]	Loss=0.4493	acc=0.8474	5545.3 examples/second
# Test Loss=0.4861, Test acc=0.8400
# Saving...
#
# Epoch: 2
# [Step=50]	Loss=0.4015	acc=0.8626	4257.4 examples/second
# [Step=100]	Loss=0.3977	acc=0.8644	5358.7 examples/second
# [Step=150]	Loss=0.3932	acc=0.8657	4672.9 examples/second
# Test Loss=0.4563, Test acc=0.8506
# Saving...
#
# Epoch: 3
# [Step=50]	Loss=0.3672	acc=0.8736	4590.3 examples/second
# [Step=100]	Loss=0.3630	acc=0.8760	5377.9 examples/second
# [Step=150]	Loss=0.3602	acc=0.8772	5171.1 examples/second
# Test Loss=0.4349, Test acc=0.8571
# Saving...
#
# Epoch: 4
# [Step=50]	Loss=0.3642	acc=0.8766	4532.7 examples/second
# [Step=100]	Loss=0.3518	acc=0.8814	5147.2 examples/second
# [Step=150]	Loss=0.3464	acc=0.8817	4899.6 examples/second
# Test Loss=0.4222, Test acc=0.8604
# Saving...
#
# Epoch: 5
# [Step=50]	Loss=0.3257	acc=0.8888	4720.8 examples/second
# [Step=100]	Loss=0.3213	acc=0.8888	5471.4 examples/second
# [Step=150]	Loss=0.3226	acc=0.8883	4967.2 examples/second
# Test Loss=0.4114, Test acc=0.8647
# Saving...
#
# Epoch: 6
# [Step=50]	Loss=0.3178	acc=0.8902	4660.0 examples/second
# [Step=100]	Loss=0.3156	acc=0.8924	5447.3 examples/second
# [Step=150]	Loss=0.3156	acc=0.8921	5074.5 examples/second
# Test Loss=0.4047, Test acc=0.8655
# Saving...
#
# Epoch: 7
# [Step=50]	Loss=0.3055	acc=0.8928	4676.6 examples/second
# [Step=100]	Loss=0.2967	acc=0.8961	5581.4 examples/second
# [Step=150]	Loss=0.2973	acc=0.8967	5365.6 examples/second
# Test Loss=0.3983, Test acc=0.8678
# Saving...
#
# Epoch: 8
# [Step=50]	Loss=0.2974	acc=0.8972	4413.5 examples/second
# [Step=100]	Loss=0.2931	acc=0.8993	5116.7 examples/second
# [Step=150]	Loss=0.2927	acc=0.8988	5141.7 examples/second
# Test Loss=0.3944, Test acc=0.8673
#
# Epoch: 9
# [Step=50]	Loss=0.2793	acc=0.9050	4438.4 examples/second
# [Step=100]	Loss=0.2827	acc=0.9017	5128.2 examples/second
# [Step=150]	Loss=0.2834	acc=0.9014	5173.8 examples/second
# Test Loss=0.3893, Test acc=0.8696
# Saving...
#
# Epoch: 10
# [Step=50]	Loss=0.2822	acc=0.9024	4584.8 examples/second
# [Step=100]	Loss=0.2865	acc=0.9018	5596.4 examples/second
# [Step=150]	Loss=0.2834	acc=0.9028	5132.0 examples/second
# Test Loss=0.3846, Test acc=0.8721
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.2829	acc=0.9007	4566.6 examples/second
# [Step=100]	Loss=0.2764	acc=0.9050	5075.8 examples/second
# [Step=150]	Loss=0.2750	acc=0.9059	5071.9 examples/second
# Test Loss=0.3816, Test acc=0.8732
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.2621	acc=0.9112	4527.1 examples/second
# [Step=100]	Loss=0.2703	acc=0.9086	5305.2 examples/second
# [Step=150]	Loss=0.2704	acc=0.9079	5334.8 examples/second
# Test Loss=0.3794, Test acc=0.8747
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.2652	acc=0.9062	4561.7 examples/second
# [Step=100]	Loss=0.2632	acc=0.9083	5360.3 examples/second
# [Step=150]	Loss=0.2635	acc=0.9094	5159.8 examples/second
# Test Loss=0.3758, Test acc=0.8756
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2579	acc=0.9102	4611.8 examples/second
# [Step=100]	Loss=0.2587	acc=0.9111	4760.7 examples/second
# [Step=150]	Loss=0.2576	acc=0.9117	4856.3 examples/second
# Test Loss=0.3755, Test acc=0.8767
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.2534	acc=0.9120	4618.7 examples/second
# [Step=100]	Loss=0.2517	acc=0.9134	5059.0 examples/second
# [Step=150]	Loss=0.2536	acc=0.9122	5380.1 examples/second
# Test Loss=0.3727, Test acc=0.8771
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2451	acc=0.9167	4690.8 examples/second
# [Step=100]	Loss=0.2477	acc=0.9162	5418.5 examples/second
# [Step=150]	Loss=0.2500	acc=0.9144	5037.7 examples/second
# Test Loss=0.3710, Test acc=0.8774
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2512	acc=0.9134	4559.9 examples/second
# [Step=100]	Loss=0.2475	acc=0.9148	4872.8 examples/second
# [Step=150]	Loss=0.2484	acc=0.9143	5459.7 examples/second
# Test Loss=0.3689, Test acc=0.8797
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2347	acc=0.9199	4221.7 examples/second
# [Step=100]	Loss=0.2414	acc=0.9171	5374.9 examples/second
# [Step=150]	Loss=0.2433	acc=0.9164	5524.3 examples/second
# Test Loss=0.3653, Test acc=0.8789
#
# Epoch: 19
# [Step=50]	Loss=0.2429	acc=0.9149	4555.8 examples/second
# [Step=100]	Loss=0.2410	acc=0.9169	5456.6 examples/second
# [Step=150]	Loss=0.2412	acc=0.9160	5501.3 examples/second
# Test Loss=0.3648, Test acc=0.8799
# Saving...

# %%
# Check sparsity of the finetuned model, make sure it's not changed
net.load_state_dict(torch.load("net_after_finetune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = np.array(layer.weight.data.cpu())
        # Count number of zeros
        zeros = np.count_nonzero(np_weight==0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.4.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.4.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.5.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.5.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=0.3648, Test accuracy=0.8799

# %% [markdown]
# ### Lab2 (d) Iterative pruning

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    
    net.train()
    if epoch<10:
        for name,layer in net.named_modules():
            if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                # Increase model sparsity
                q = 8 * (epoch+1)
                prune_by_percentage(layer, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0496	acc=0.9835	4290.6 examples/second
# [Step=100]	Loss=0.0491	acc=0.9841	5099.3 examples/second
# [Step=150]	Loss=0.0498	acc=0.9838	5466.7 examples/second
# Test Loss=0.3238, Test acc=0.9145
#
# Epoch: 1
# [Step=50]	Loss=0.0522	acc=0.9826	4359.7 examples/second
# [Step=100]	Loss=0.0496	acc=0.9838	5113.8 examples/second
# [Step=150]	Loss=0.0496	acc=0.9839	5446.2 examples/second
# Test Loss=0.3266, Test acc=0.9143
#
# Epoch: 2
# [Step=50]	Loss=0.0520	acc=0.9830	4380.5 examples/second
# [Step=100]	Loss=0.0511	acc=0.9838	4935.9 examples/second
# [Step=150]	Loss=0.0511	acc=0.9836	5094.2 examples/second
# Test Loss=0.3297, Test acc=0.9127
#
# Epoch: 3
# [Step=50]	Loss=0.0592	acc=0.9809	4234.2 examples/second
# [Step=100]	Loss=0.0583	acc=0.9810	5341.6 examples/second
# [Step=150]	Loss=0.0572	acc=0.9810	5166.1 examples/second
# Test Loss=0.3317, Test acc=0.9110
#
# Epoch: 4
# [Step=50]	Loss=0.0720	acc=0.9748	4497.0 examples/second
# [Step=100]	Loss=0.0687	acc=0.9761	5421.8 examples/second
# [Step=150]	Loss=0.0686	acc=0.9763	5287.5 examples/second
# Test Loss=0.3376, Test acc=0.9096
#
# Epoch: 5
# [Step=50]	Loss=0.0895	acc=0.9683	4471.7 examples/second
# [Step=100]	Loss=0.0886	acc=0.9689	5222.6 examples/second
# [Step=150]	Loss=0.0858	acc=0.9704	5008.1 examples/second
# Test Loss=0.3366, Test acc=0.9045
#
# Epoch: 6
# [Step=50]	Loss=0.1348	acc=0.9523	4411.7 examples/second
# [Step=100]	Loss=0.1245	acc=0.9567	5183.7 examples/second
# [Step=150]	Loss=0.1204	acc=0.9580	5469.9 examples/second
# Test Loss=0.3363, Test acc=0.9017
#
# Epoch: 7
# [Step=50]	Loss=0.1781	acc=0.9380	4440.4 examples/second
# [Step=100]	Loss=0.1717	acc=0.9400	5153.7 examples/second
# [Step=150]	Loss=0.1649	acc=0.9426	5201.4 examples/second
# Test Loss=0.3489, Test acc=0.8937
#
# Epoch: 8
# [Step=50]	Loss=0.2764	acc=0.9066	4642.1 examples/second
# [Step=100]	Loss=0.2566	acc=0.9121	5490.5 examples/second
# [Step=150]	Loss=0.2459	acc=0.9147	5507.5 examples/second
# Test Loss=0.3710, Test acc=0.8813
#
# Epoch: 9
# [Step=50]	Loss=0.5576	acc=0.8102	4441.2 examples/second
# [Step=100]	Loss=0.5119	acc=0.8266	5338.7 examples/second
# [Step=150]	Loss=0.4819	acc=0.8372	5236.0 examples/second
# Test Loss=0.4760, Test acc=0.8465
#
# Epoch: 10
# [Step=50]	Loss=0.3720	acc=0.8707	4228.5 examples/second
# [Step=100]	Loss=0.3723	acc=0.8725	5039.4 examples/second
# [Step=150]	Loss=0.3712	acc=0.8734	5263.2 examples/second
# Test Loss=0.4439, Test acc=0.8559
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.3435	acc=0.8825	4356.4 examples/second
# [Step=100]	Loss=0.3451	acc=0.8830	5291.5 examples/second
# [Step=150]	Loss=0.3425	acc=0.8832	5202.2 examples/second
# Test Loss=0.4252, Test acc=0.8623
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.3289	acc=0.8877	4442.9 examples/second
# [Step=100]	Loss=0.3242	acc=0.8867	5267.9 examples/second
# [Step=150]	Loss=0.3239	acc=0.8873	5199.4 examples/second
# Test Loss=0.4133, Test acc=0.8668
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.3053	acc=0.8962	4538.0 examples/second
# [Step=100]	Loss=0.3094	acc=0.8947	5093.4 examples/second
# [Step=150]	Loss=0.3099	acc=0.8930	5180.0 examples/second
# Test Loss=0.4036, Test acc=0.8677
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2919	acc=0.9055	4611.4 examples/second
# [Step=100]	Loss=0.2927	acc=0.9020	5351.1 examples/second
# [Step=150]	Loss=0.2942	acc=0.9012	4997.5 examples/second
# Test Loss=0.3974, Test acc=0.8695
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.2862	acc=0.9002	4467.7 examples/second
# [Step=100]	Loss=0.2841	acc=0.9024	5468.3 examples/second
# [Step=150]	Loss=0.2839	acc=0.9024	5196.0 examples/second
# Test Loss=0.3922, Test acc=0.8700
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2754	acc=0.9038	4256.4 examples/second
# [Step=100]	Loss=0.2746	acc=0.9049	4965.1 examples/second
# [Step=150]	Loss=0.2784	acc=0.9028	5023.5 examples/second
# Test Loss=0.3870, Test acc=0.8712
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2698	acc=0.9045	4438.9 examples/second
# [Step=100]	Loss=0.2709	acc=0.9059	4952.4 examples/second
# [Step=150]	Loss=0.2723	acc=0.9062	5435.6 examples/second
# Test Loss=0.3830, Test acc=0.8728
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2602	acc=0.9080	4643.5 examples/second
# [Step=100]	Loss=0.2659	acc=0.9063	5306.1 examples/second
# [Step=150]	Loss=0.2671	acc=0.9069	5285.3 examples/second
# Test Loss=0.3789, Test acc=0.8744
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2570	acc=0.9114	4516.1 examples/second
# [Step=100]	Loss=0.2552	acc=0.9128	5340.8 examples/second
# [Step=150]	Loss=0.2560	acc=0.9115	5055.8 examples/second
# Test Loss=0.3767, Test acc=0.8756
# Saving...

# %%
# Check sparsity of the final model, make sure it's 80%
net.load_state_dict(torch.load("net_after_iterative_prune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # change q value
        prune_by_percentage(layer, q=40.0)
        
        # Optional: Check the sparsity you achieve in each layer
        # Convert the weight of "layer" to numpy array
        np_weight = np.array(layer.weight.data.cpu())
        # Count number of zeros
        zeros = np.count_nonzero(np_weight==0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.4.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.4.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.5.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.5.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=0.3767, Test accuracy=0.8756

# %% [markdown]
# ### Lab2 (e) Global iterative pruning

# %%
def global_prune_by_percentage(net, q=80.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least 
    significant weight parameters will be pruned.
    """
    # A list to gather all the weights
    flattened_weights = []
    # Find global pruning threshold
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            np_weight = np.array(layer.weight.data.cpu())
            
            # Flatten the weight and append to flattened_weights
            flattened_weights.append(np_weight.flatten())
    
    # Concate all weights into a np array
    flattened_weights = np.concatenate(flattened_weights)
    # Find global pruning threshold
    thres = np.percentile(np.absolute(flattened_weights), q)
    
    # Apply pruning threshold to all layers
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            np_weight = np.array(layer.weight.data.cpu())
            
            # Generate a binary mask same shape as weight to decide which element to prune
            bin_mask = np.where(np.absolute(np_weight) >= thres, 1, 0)
            
            # Convert mask to torch tensor and put on GPU
            bin_mask = torch.from_numpy(bin_mask).to(device)
            
            # Multiply the weight by mask to perform pruning
            layer.weight.data = layer.weight.data * bin_mask

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    q=(epoch+1)*8
    
    net.train()
    # Increase model sparsity
    if epoch<10:
        global_prune_by_percentage(net, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_global_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0467	acc=0.9850	2485.7 examples/second
# [Step=100]	Loss=0.0478	acc=0.9846	4671.5 examples/second
# [Step=150]	Loss=0.0469	acc=0.9851	4546.3 examples/second
# Test Loss=0.3259, Test acc=0.9138
#
# Epoch: 1
# [Step=50]	Loss=0.0482	acc=0.9845	3239.1 examples/second
# [Step=100]	Loss=0.0500	acc=0.9842	4113.3 examples/second
# [Step=150]	Loss=0.0484	acc=0.9847	4569.2 examples/second
# Test Loss=0.3250, Test acc=0.9136
#
# Epoch: 2
# [Step=50]	Loss=0.0481	acc=0.9853	3279.7 examples/second
# [Step=100]	Loss=0.0502	acc=0.9838	4598.0 examples/second
# [Step=150]	Loss=0.0509	acc=0.9835	4969.4 examples/second
# Test Loss=0.3245, Test acc=0.9136
#
# Epoch: 3
# [Step=50]	Loss=0.0496	acc=0.9851	3339.6 examples/second
# [Step=100]	Loss=0.0500	acc=0.9849	4607.8 examples/second
# [Step=150]	Loss=0.0499	acc=0.9846	4868.5 examples/second
# Test Loss=0.3274, Test acc=0.9132
#
# Epoch: 4
# [Step=50]	Loss=0.0601	acc=0.9793	3584.7 examples/second
# [Step=100]	Loss=0.0609	acc=0.9798	5270.6 examples/second
# [Step=150]	Loss=0.0595	acc=0.9803	5153.1 examples/second
# Test Loss=0.3230, Test acc=0.9129
#
# Epoch: 5
# [Step=50]	Loss=0.0726	acc=0.9750	4105.4 examples/second
# [Step=100]	Loss=0.0732	acc=0.9748	5286.1 examples/second
# [Step=150]	Loss=0.0719	acc=0.9753	5378.0 examples/second
# Test Loss=0.3255, Test acc=0.9079
#
# Epoch: 6
# [Step=50]	Loss=0.0928	acc=0.9672	3657.7 examples/second
# [Step=100]	Loss=0.0925	acc=0.9670	5246.9 examples/second
# [Step=150]	Loss=0.0903	acc=0.9688	5294.4 examples/second
# Test Loss=0.3262, Test acc=0.9060
#
# Epoch: 7
# [Step=50]	Loss=0.1211	acc=0.9598	3835.1 examples/second
# [Step=100]	Loss=0.1227	acc=0.9589	5676.2 examples/second
# [Step=150]	Loss=0.1229	acc=0.9582	4917.4 examples/second
# Test Loss=0.3261, Test acc=0.9019
#
# Epoch: 8
# [Step=50]	Loss=0.2060	acc=0.9300	3436.4 examples/second
# [Step=100]	Loss=0.1990	acc=0.9328	5215.6 examples/second
# [Step=150]	Loss=0.1883	acc=0.9361	5592.2 examples/second
# Test Loss=0.3405, Test acc=0.8883
#
# Epoch: 9
# [Step=50]	Loss=0.4111	acc=0.8577	3465.2 examples/second
# [Step=100]	Loss=0.3903	acc=0.8662	4695.2 examples/second
# [Step=150]	Loss=0.3746	acc=0.8722	5551.5 examples/second
# Test Loss=0.4238, Test acc=0.8550
#
# Epoch: 10
# [Step=50]	Loss=0.3162	acc=0.8948	3625.6 examples/second
# [Step=100]	Loss=0.3164	acc=0.8930	4897.0 examples/second
# [Step=150]	Loss=0.3148	acc=0.8943	5607.3 examples/second
# Test Loss=0.3988, Test acc=0.8645
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.2979	acc=0.8979	3894.0 examples/second
# [Step=100]	Loss=0.2898	acc=0.9016	5080.9 examples/second
# [Step=150]	Loss=0.2862	acc=0.9029	5079.4 examples/second
# Test Loss=0.3848, Test acc=0.8711
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.2790	acc=0.9052	3594.6 examples/second
# [Step=100]	Loss=0.2775	acc=0.9056	4474.7 examples/second
# [Step=150]	Loss=0.2763	acc=0.9057	4787.5 examples/second
# Test Loss=0.3750, Test acc=0.8734
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.2660	acc=0.9120	3535.1 examples/second
# [Step=100]	Loss=0.2629	acc=0.9112	5507.6 examples/second
# [Step=150]	Loss=0.2601	acc=0.9129	5368.1 examples/second
# Test Loss=0.3676, Test acc=0.8750
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2599	acc=0.9137	3804.9 examples/second
# [Step=100]	Loss=0.2543	acc=0.9153	4836.6 examples/second
# [Step=150]	Loss=0.2543	acc=0.9143	5069.6 examples/second
# Test Loss=0.3639, Test acc=0.8761
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.2541	acc=0.9112	3979.9 examples/second
# [Step=100]	Loss=0.2441	acc=0.9163	5283.0 examples/second
# [Step=150]	Loss=0.2436	acc=0.9174	4948.9 examples/second
# Test Loss=0.3598, Test acc=0.8795
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2375	acc=0.9192	3558.3 examples/second
# [Step=100]	Loss=0.2416	acc=0.9178	5174.7 examples/second
# [Step=150]	Loss=0.2412	acc=0.9186	4724.1 examples/second
# Test Loss=0.3551, Test acc=0.8812
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2365	acc=0.9206	3968.0 examples/second
# [Step=100]	Loss=0.2356	acc=0.9205	5208.4 examples/second
# [Step=150]	Loss=0.2370	acc=0.9196	5415.7 examples/second
# Test Loss=0.3523, Test acc=0.8820
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2319	acc=0.9235	3596.8 examples/second
# [Step=100]	Loss=0.2358	acc=0.9215	5129.3 examples/second
# [Step=150]	Loss=0.2312	acc=0.9227	4747.9 examples/second
# Test Loss=0.3493, Test acc=0.8830
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2275	acc=0.9237	3480.1 examples/second
# [Step=100]	Loss=0.2241	acc=0.9232	5095.7 examples/second
# [Step=150]	Loss=0.2252	acc=0.9230	4805.8 examples/second
# Test Loss=0.3483, Test acc=0.8840
# Saving...

# %%
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))

zeros_sum = 0
total_sum = 0
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = np.array(layer.weight.data.cpu())
        # Count number of zeros
        zeros = np.count_nonzero(np_weight==0)
        # Count number of parameters
        total = np_weight.size
        zeros_sum+=zeros
        total_sum+=total
        print('Sparsity of '+name+': '+str(zeros/total))
print('Total sparsity of: '+str(zeros_sum/total_sum))
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.3101851851851852
# Sparsity of body_op.0.conv1.0.conv: 0.6566840277777778
# Sparsity of body_op.0.conv2.0.conv: 0.6384548611111112
# Sparsity of body_op.1.conv1.0.conv: 0.6258680555555556
# Sparsity of body_op.1.conv2.0.conv: 0.6480034722222222
# Sparsity of body_op.2.conv1.0.conv: 0.6310763888888888
# Sparsity of body_op.2.conv2.0.conv: 0.6692708333333334
# Sparsity of body_op.3.conv1.0.conv: 0.6243489583333334
# Sparsity of body_op.3.conv2.0.conv: 0.6886935763888888
# Sparsity of body_op.4.conv1.0.conv: 0.7253689236111112
# Sparsity of body_op.4.conv2.0.conv: 0.7822265625
# Sparsity of body_op.5.conv1.0.conv: 0.7248263888888888
# Sparsity of body_op.5.conv2.0.conv: 0.8130425347222222
# Sparsity of body_op.6.conv1.0.conv: 0.7327473958333334
# Sparsity of body_op.6.conv2.0.conv: 0.7643500434027778
# Sparsity of body_op.7.conv1.0.conv: 0.7770182291666666
# Sparsity of body_op.7.conv2.0.conv: 0.8261176215277778
# Sparsity of body_op.8.conv1.0.conv: 0.8528103298611112
# Sparsity of body_op.8.conv2.0.conv: 0.9767795138888888
# Sparsity of final_fc.linear: 0.1578125
# Total sparsity of: 0.7999970186631685
# Files already downloaded and verified
# Test Loss=0.3483, Test accuracy=0.8840

# %% [markdown]
# ### Lab 3 (b) and (c): Fixed-point quantization

# %%
# Define quantized model and load weight
Nbits = 4 #Change this value to finish (b) and (c)

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)

# %%
# Define quantized model and load weight
Nbits = 4 #Change this value to finish (b) and (c)

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=0.3861, Test accuracy=0.8972

# %%
# Quantized model finetuning
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)   

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=0.0695	acc=0.9753	3643.5 examples/second
# [Step=100]	Loss=0.0694	acc=0.9755	4428.9 examples/second
# [Step=150]	Loss=0.0678	acc=0.9757	4185.1 examples/second
# Test Loss=0.3357, Test acc=0.9089
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.0756	acc=0.9727	1880.1 examples/second
# [Step=250]	Loss=0.0616	acc=0.9789	4760.3 examples/second
# [Step=300]	Loss=0.0595	acc=0.9799	4256.6 examples/second
# [Step=350]	Loss=0.0594	acc=0.9799	4392.5 examples/second
# Test Loss=0.3325, Test acc=0.9101
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.0602	acc=0.9814	1772.9 examples/second
# [Step=450]	Loss=0.0650	acc=0.9775	4570.6 examples/second
# [Step=500]	Loss=0.0606	acc=0.9797	4425.2 examples/second
# [Step=550]	Loss=0.0598	acc=0.9795	4039.8 examples/second
# Test Loss=0.3345, Test acc=0.9110
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.0598	acc=0.9805	1769.4 examples/second
# [Step=650]	Loss=0.0581	acc=0.9814	4467.1 examples/second
# [Step=700]	Loss=0.0600	acc=0.9804	3941.3 examples/second
# [Step=750]	Loss=0.0592	acc=0.9807	4065.8 examples/second
# Test Loss=0.3325, Test acc=0.9112
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.0597	acc=0.9797	1684.3 examples/second
# [Step=850]	Loss=0.0594	acc=0.9800	4145.8 examples/second
# [Step=900]	Loss=0.0605	acc=0.9794	4295.2 examples/second
# [Step=950]	Loss=0.0585	acc=0.9804	4533.2 examples/second
# Test Loss=0.3326, Test acc=0.9116
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.0580	acc=0.9816	1709.0 examples/second
# [Step=1050]	Loss=0.0548	acc=0.9825	4708.9 examples/second
# [Step=1100]	Loss=0.0560	acc=0.9820	4463.2 examples/second
# [Step=1150]	Loss=0.0569	acc=0.9817	4346.4 examples/second
# Test Loss=0.3324, Test acc=0.9119
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=0.0582	acc=0.9814	1703.4 examples/second
# [Step=1250]	Loss=0.0587	acc=0.9803	3890.4 examples/second
# [Step=1300]	Loss=0.0564	acc=0.9814	4356.0 examples/second
# [Step=1350]	Loss=0.0557	acc=0.9813	4613.8 examples/second
# Test Loss=0.3321, Test acc=0.9120
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=0.0522	acc=0.9819	1708.4 examples/second
# [Step=1450]	Loss=0.0551	acc=0.9822	4325.7 examples/second
# [Step=1500]	Loss=0.0545	acc=0.9819	4111.0 examples/second
# [Step=1550]	Loss=0.0568	acc=0.9810	4269.5 examples/second
# Test Loss=0.3296, Test acc=0.9120
#
# Epoch: 8
# [Step=1600]	Loss=0.0559	acc=0.9812	1891.7 examples/second
# [Step=1650]	Loss=0.0585	acc=0.9799	4244.2 examples/second
# [Step=1700]	Loss=0.0574	acc=0.9809	4346.4 examples/second
# [Step=1750]	Loss=0.0561	acc=0.9814	4283.1 examples/second
# Test Loss=0.3355, Test acc=0.9116
#
# Epoch: 9
# [Step=1800]	Loss=0.0575	acc=0.9806	2027.9 examples/second
# [Step=1850]	Loss=0.0581	acc=0.9813	4534.9 examples/second
# [Step=1900]	Loss=0.0578	acc=0.9814	4107.1 examples/second
# [Step=1950]	Loss=0.0565	acc=0.9817	4009.7 examples/second
# Test Loss=0.3349, Test acc=0.9125
# Saving...
#
# Epoch: 10
# [Step=2000]	Loss=0.0538	acc=0.9831	1726.9 examples/second
# [Step=2050]	Loss=0.0561	acc=0.9821	4542.4 examples/second
# [Step=2100]	Loss=0.0552	acc=0.9822	4150.9 examples/second
# [Step=2150]	Loss=0.0554	acc=0.9820	4399.6 examples/second
# Test Loss=0.3303, Test acc=0.9128
# Saving...
#
# Epoch: 11
# [Step=2200]	Loss=0.0500	acc=0.9841	1617.5 examples/second
# [Step=2250]	Loss=0.0545	acc=0.9821	4480.3 examples/second
# [Step=2300]	Loss=0.0549	acc=0.9823	4252.7 examples/second
# [Step=2350]	Loss=0.0554	acc=0.9821	4217.4 examples/second
# Test Loss=0.3327, Test acc=0.9116
#
# Epoch: 12
# [Step=2400]	Loss=0.0528	acc=0.9814	1964.8 examples/second
# [Step=2450]	Loss=0.0541	acc=0.9817	4294.5 examples/second
# [Step=2500]	Loss=0.0551	acc=0.9815	4520.1 examples/second
# Test Loss=0.3308, Test acc=0.9116
#
# Epoch: 13
# [Step=2550]	Loss=0.0443	acc=0.9824	1895.1 examples/second
# [Step=2600]	Loss=0.0538	acc=0.9817	4204.2 examples/second
# [Step=2650]	Loss=0.0534	acc=0.9822	4491.9 examples/second
# [Step=2700]	Loss=0.0542	acc=0.9824	4058.0 examples/second
# Test Loss=0.3363, Test acc=0.9124
#
# Epoch: 14
# [Step=2750]	Loss=0.0535	acc=0.9818	1876.4 examples/second
# [Step=2800]	Loss=0.0552	acc=0.9807	4215.0 examples/second
# [Step=2850]	Loss=0.0534	acc=0.9819	4061.0 examples/second
# [Step=2900]	Loss=0.0537	acc=0.9821	4548.5 examples/second
# Test Loss=0.3309, Test acc=0.9122
#
# Epoch: 15
# [Step=2950]	Loss=0.0619	acc=0.9770	1932.7 examples/second
# [Step=3000]	Loss=0.0523	acc=0.9833	4212.5 examples/second
# [Step=3050]	Loss=0.0539	acc=0.9826	4198.1 examples/second
# [Step=3100]	Loss=0.0546	acc=0.9820	4043.0 examples/second
# Test Loss=0.3324, Test acc=0.9135
# Saving...
#
# Epoch: 16
# [Step=3150]	Loss=0.0443	acc=0.9872	1783.3 examples/second
# [Step=3200]	Loss=0.0506	acc=0.9829	4394.5 examples/second
# [Step=3250]	Loss=0.0522	acc=0.9827	4599.6 examples/second
# [Step=3300]	Loss=0.0532	acc=0.9824	4687.1 examples/second
# Test Loss=0.3332, Test acc=0.9122
#
# Epoch: 17
# [Step=3350]	Loss=0.0509	acc=0.9842	1907.8 examples/second
# [Step=3400]	Loss=0.0516	acc=0.9837	4332.0 examples/second
# [Step=3450]	Loss=0.0523	acc=0.9834	4181.9 examples/second
# [Step=3500]	Loss=0.0533	acc=0.9829	4137.8 examples/second
# Test Loss=0.3376, Test acc=0.9119
#
# Epoch: 18
# [Step=3550]	Loss=0.0564	acc=0.9824	2032.0 examples/second
# [Step=3600]	Loss=0.0565	acc=0.9819	4325.7 examples/second
# [Step=3650]	Loss=0.0551	acc=0.9823	4442.1 examples/second
# [Step=3700]	Loss=0.0536	acc=0.9827	4094.2 examples/second
# Test Loss=0.3380, Test acc=0.9123
#
# Epoch: 19
# [Step=3750]	Loss=0.0487	acc=0.9839	1954.8 examples/second
# [Step=3800]	Loss=0.0513	acc=0.9833	4210.4 examples/second
# [Step=3850]	Loss=0.0522	acc=0.9832	4012.0 examples/second
# [Step=3900]	Loss=0.0525	acc=0.9828	4198.2 examples/second
# Test Loss=0.3370, Test acc=0.9117
# Files already downloaded and verified
# Test Loss=0.3324, Test accuracy=0.9135

# %% [markdown]
# ### Lab3 (d) Quantize pruned model

# %%
# Define quantized model and load weight
Nbits = 2 #Change this value to finish (d)

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=7.6773, Test accuracy=0.1090

# %%
# Quantized model finetuning
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=2.3051	acc=0.1413	3317.1 examples/second
# [Step=100]	Loss=2.2457	acc=0.1537	4217.5 examples/second
# [Step=150]	Loss=2.2204	acc=0.1608	4396.4 examples/second
# Test Loss=2.1529, Test acc=0.1698
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=2.1676	acc=0.1758	1671.0 examples/second
# [Step=250]	Loss=2.1451	acc=0.1884	4527.0 examples/second
# [Step=300]	Loss=2.1382	acc=0.1906	4057.7 examples/second
# [Step=350]	Loss=2.1284	acc=0.2004	4184.5 examples/second
# Test Loss=2.1173, Test acc=0.2061
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=2.1176	acc=0.2168	1691.8 examples/second
# [Step=450]	Loss=2.1158	acc=0.2144	3946.6 examples/second
# [Step=500]	Loss=2.1077	acc=0.2191	3963.3 examples/second
# [Step=550]	Loss=2.1015	acc=0.2211	4413.4 examples/second
# Test Loss=2.0996, Test acc=0.2257
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=2.0880	acc=0.2282	1657.9 examples/second
# [Step=650]	Loss=2.0864	acc=0.2274	4221.5 examples/second
# [Step=700]	Loss=2.0796	acc=0.2322	4393.5 examples/second
# [Step=750]	Loss=2.0732	acc=0.2353	4706.9 examples/second
# Test Loss=2.0480, Test acc=0.2517
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=2.0565	acc=0.2451	1832.1 examples/second
# [Step=850]	Loss=2.0628	acc=0.2433	3997.4 examples/second
# [Step=900]	Loss=2.0575	acc=0.2452	4348.2 examples/second
# [Step=950]	Loss=2.0538	acc=0.2471	4062.4 examples/second
# Test Loss=2.0534, Test acc=0.2534
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=2.0424	acc=0.2637	1678.8 examples/second
# [Step=1050]	Loss=2.0356	acc=0.2609	4249.3 examples/second
# [Step=1100]	Loss=2.0323	acc=0.2578	4246.0 examples/second
# [Step=1150]	Loss=2.0302	acc=0.2570	4283.7 examples/second
# Test Loss=2.0267, Test acc=0.2597
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=2.0146	acc=0.2557	1804.6 examples/second
# [Step=1250]	Loss=2.0208	acc=0.2568	4247.6 examples/second
# [Step=1300]	Loss=2.0176	acc=0.2602	4457.5 examples/second
# [Step=1350]	Loss=2.0153	acc=0.2613	4095.1 examples/second
# Test Loss=2.0331, Test acc=0.2537
#
# Epoch: 7
# [Step=1400]	Loss=2.0042	acc=0.2683	1821.6 examples/second
# [Step=1450]	Loss=2.0011	acc=0.2695	4221.1 examples/second
# [Step=1500]	Loss=2.0008	acc=0.2722	4293.4 examples/second
# [Step=1550]	Loss=1.9973	acc=0.2719	4291.1 examples/second
# Test Loss=2.0052, Test acc=0.2679
# Saving...
#
# Epoch: 8
# [Step=1600]	Loss=1.9914	acc=0.2651	1732.2 examples/second
# [Step=1650]	Loss=1.9853	acc=0.2748	4415.5 examples/second
# [Step=1700]	Loss=1.9819	acc=0.2776	4176.7 examples/second
# [Step=1750]	Loss=1.9764	acc=0.2794	4283.9 examples/second
# Test Loss=1.9941, Test acc=0.2780
# Saving...
#
# Epoch: 9
# [Step=1800]	Loss=1.9568	acc=0.2816	1782.7 examples/second
# [Step=1850]	Loss=1.9687	acc=0.2792	4502.6 examples/second
# [Step=1900]	Loss=1.9662	acc=0.2788	3944.6 examples/second
# [Step=1950]	Loss=1.9620	acc=0.2806	4266.1 examples/second
# Test Loss=1.9773, Test acc=0.2611
#
# Epoch: 10
# [Step=2000]	Loss=1.9500	acc=0.2850	1833.0 examples/second
# [Step=2050]	Loss=1.9502	acc=0.2822	4194.0 examples/second
# [Step=2100]	Loss=1.9442	acc=0.2833	4301.3 examples/second
# [Step=2150]	Loss=1.9412	acc=0.2872	3888.5 examples/second
# Test Loss=1.9589, Test acc=0.2784
# Saving...
#
# Epoch: 11
# [Step=2200]	Loss=1.9348	acc=0.2884	1728.8 examples/second
# [Step=2250]	Loss=1.9352	acc=0.2892	3823.9 examples/second
# [Step=2300]	Loss=1.9257	acc=0.2936	4260.9 examples/second
# [Step=2350]	Loss=1.9217	acc=0.2943	4258.5 examples/second
# Test Loss=1.8978, Test acc=0.2972
# Saving...
#
# Epoch: 12
# [Step=2400]	Loss=1.9106	acc=0.2969	1820.0 examples/second
# [Step=2450]	Loss=1.9048	acc=0.2982	4291.7 examples/second
# [Step=2500]	Loss=1.8977	acc=0.2996	3891.1 examples/second
# Test Loss=1.8969, Test acc=0.2916
#
# Epoch: 13
# [Step=2550]	Loss=1.8625	acc=0.3184	2032.3 examples/second
# [Step=2600]	Loss=1.8790	acc=0.3067	4740.8 examples/second
# [Step=2650]	Loss=1.8732	acc=0.3086	4066.4 examples/second
# [Step=2700]	Loss=1.8680	acc=0.3147	4300.6 examples/second
# Test Loss=1.8951, Test acc=0.2941
#
# Epoch: 14
# [Step=2750]	Loss=1.8796	acc=0.2871	2027.3 examples/second
# [Step=2800]	Loss=1.8482	acc=0.3124	4689.8 examples/second
# [Step=2850]	Loss=1.8461	acc=0.3129	4455.7 examples/second
# [Step=2900]	Loss=1.8433	acc=0.3147	4115.4 examples/second
# Test Loss=1.8547, Test acc=0.3044
# Saving...
#
# Epoch: 15
# [Step=2950]	Loss=1.8233	acc=0.3285	1905.2 examples/second
# [Step=3000]	Loss=1.8215	acc=0.3258	4200.0 examples/second
# [Step=3050]	Loss=1.8226	acc=0.3217	4209.8 examples/second
# [Step=3100]	Loss=1.8218	acc=0.3211	4301.7 examples/second
# Test Loss=1.8381, Test acc=0.3057
# Saving...
#
# Epoch: 16
# [Step=3150]	Loss=1.7839	acc=0.3209	1783.3 examples/second
# [Step=3200]	Loss=1.7998	acc=0.3215	4316.7 examples/second
# [Step=3250]	Loss=1.7971	acc=0.3236	4010.4 examples/second
# [Step=3300]	Loss=1.7996	acc=0.3234	4480.6 examples/second
# Test Loss=1.8815, Test acc=0.2991
#
# Epoch: 17
# [Step=3350]	Loss=1.7870	acc=0.3316	2080.1 examples/second
# [Step=3400]	Loss=1.7909	acc=0.3284	4328.8 examples/second
# [Step=3450]	Loss=1.7882	acc=0.3297	4350.8 examples/second
# [Step=3500]	Loss=1.7847	acc=0.3275	4435.7 examples/second
# Test Loss=1.8222, Test acc=0.3092
# Saving...
#
# Epoch: 18
# [Step=3550]	Loss=1.7681	acc=0.3333	1756.3 examples/second
# [Step=3600]	Loss=1.7559	acc=0.3402	4407.0 examples/second
# [Step=3650]	Loss=1.7600	acc=0.3373	4132.0 examples/second
# [Step=3700]	Loss=1.7620	acc=0.3360	4458.1 examples/second
# Test Loss=1.8783, Test acc=0.2792
#
# Epoch: 19
# [Step=3750]	Loss=1.7662	acc=0.3401	1974.4 examples/second
# [Step=3800]	Loss=1.7634	acc=0.3399	4739.9 examples/second
# [Step=3850]	Loss=1.7553	acc=0.3416	4251.4 examples/second
# [Step=3900]	Loss=1.7500	acc=0.3427	4509.8 examples/second
# Test Loss=1.8240, Test acc=0.3029
# Files already downloaded and verified
# Test Loss=1.8222, Test accuracy=0.3092

# %% [markdown]
# ### Lab3 (e) Prune quantized model

# %%
net = ResNetCIFAR(num_layers=20, Nbits=4)
net = net.to(device)

net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    q=(epoch+1)*8
    
    net.train()
    # Increase model sparsity
    if epoch<10:
        global_prune_by_percentage(net, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "quantized_net_after_global_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0696	acc=0.9746	4202.5 examples/second
# [Step=100]	Loss=0.0699	acc=0.9755	4973.2 examples/second
# [Step=150]	Loss=0.0696	acc=0.9755	4925.8 examples/second
# Test Loss=0.3433, Test acc=0.9070
#
# Epoch: 1
# [Step=50]	Loss=0.0775	acc=0.9730	3760.1 examples/second
# [Step=100]	Loss=0.0772	acc=0.9735	4660.5 examples/second
# [Step=150]	Loss=0.0743	acc=0.9743	4555.3 examples/second
# Test Loss=0.3509, Test acc=0.9046
#
# Epoch: 2
# [Step=50]	Loss=0.0834	acc=0.9703	3924.2 examples/second
# [Step=100]	Loss=0.0847	acc=0.9701	4429.4 examples/second
# [Step=150]	Loss=0.0827	acc=0.9708	5240.3 examples/second
# Test Loss=0.3646, Test acc=0.9031
#
# Epoch: 3
# [Step=50]	Loss=0.1089	acc=0.9617	3868.4 examples/second
# [Step=100]	Loss=0.1063	acc=0.9624	4775.1 examples/second
# [Step=150]	Loss=0.1076	acc=0.9617	4985.0 examples/second
# Test Loss=0.3781, Test acc=0.8961
#
# Epoch: 4
# [Step=50]	Loss=0.1309	acc=0.9545	3908.8 examples/second
# [Step=100]	Loss=0.1362	acc=0.9518	4735.9 examples/second
# [Step=150]	Loss=0.1347	acc=0.9522	4563.4 examples/second
# Test Loss=0.4003, Test acc=0.8876
#
# Epoch: 5
# [Step=50]	Loss=0.1775	acc=0.9361	3973.1 examples/second
# [Step=100]	Loss=0.1799	acc=0.9357	4452.0 examples/second
# [Step=150]	Loss=0.1761	acc=0.9365	4669.1 examples/second
# Test Loss=0.4304, Test acc=0.8758
#
# Epoch: 6
# [Step=50]	Loss=0.2574	acc=0.9074	3970.1 examples/second
# [Step=100]	Loss=0.2589	acc=0.9073	4719.2 examples/second
# [Step=150]	Loss=0.2573	acc=0.9086	4803.0 examples/second
# Test Loss=0.4973, Test acc=0.8518
#
# Epoch: 7
# [Step=50]	Loss=0.4713	acc=0.8389	4051.3 examples/second
# [Step=100]	Loss=0.4654	acc=0.8419	4640.1 examples/second
# [Step=150]	Loss=0.4697	acc=0.8408	4514.8 examples/second
# Test Loss=0.6322, Test acc=0.8066
#
# Epoch: 8
# [Step=50]	Loss=1.1299	acc=0.6565	3694.7 examples/second
# [Step=100]	Loss=1.1223	acc=0.6612	4755.6 examples/second
# [Step=150]	Loss=1.1223	acc=0.6608	4740.1 examples/second
# Test Loss=1.0710, Test acc=0.6789
#
# Epoch: 9
# [Step=50]	Loss=2.2989	acc=0.3954	3813.5 examples/second
# [Step=100]	Loss=2.3106	acc=0.3914	4639.7 examples/second
# [Step=150]	Loss=2.3124	acc=0.3913	4598.4 examples/second
# Test Loss=2.2254, Test acc=0.4106
#
# Epoch: 10
# [Step=50]	Loss=2.3161	acc=0.3819	3866.5 examples/second
# [Step=100]	Loss=2.3176	acc=0.3873	4409.1 examples/second
# [Step=150]	Loss=2.3207	acc=0.3879	4703.5 examples/second
# Test Loss=2.2144, Test acc=0.4120
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=2.3492	acc=0.3820	3728.4 examples/second
# [Step=100]	Loss=2.3352	acc=0.3837	4630.2 examples/second
# [Step=150]	Loss=2.3326	acc=0.3835	4677.8 examples/second
# Test Loss=2.2089, Test acc=0.4109
#
# Epoch: 12
# [Step=50]	Loss=2.2978	acc=0.3942	3804.1 examples/second
# [Step=100]	Loss=2.3155	acc=0.3917	4995.1 examples/second
# [Step=150]	Loss=2.3163	acc=0.3911	4556.8 examples/second
# Test Loss=2.2089, Test acc=0.4124
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=2.3259	acc=0.3877	3853.3 examples/second
# [Step=100]	Loss=2.3291	acc=0.3880	4604.1 examples/second
# [Step=150]	Loss=2.3240	acc=0.3875	4315.0 examples/second
# Test Loss=2.2142, Test acc=0.4117
#
# Epoch: 14
# [Step=50]	Loss=2.3341	acc=0.3841	3767.4 examples/second
# [Step=100]	Loss=2.3357	acc=0.3837	4715.6 examples/second
# [Step=150]	Loss=2.3362	acc=0.3845	4406.1 examples/second
# Test Loss=2.2118, Test acc=0.4115
#
# Epoch: 15
# [Step=50]	Loss=2.3380	acc=0.3884	4195.1 examples/second
# [Step=100]	Loss=2.3309	acc=0.3879	4881.7 examples/second
# [Step=150]	Loss=2.3229	acc=0.3891	4592.6 examples/second
# Test Loss=2.2337, Test acc=0.4125
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=2.3097	acc=0.3954	3905.7 examples/second
# [Step=100]	Loss=2.3226	acc=0.3881	4807.0 examples/second
# [Step=150]	Loss=2.3240	acc=0.3882	4441.8 examples/second
# Test Loss=2.2239, Test acc=0.4113
#
# Epoch: 17
# [Step=50]	Loss=2.3021	acc=0.3875	3768.6 examples/second
# [Step=100]	Loss=2.3213	acc=0.3827	4343.0 examples/second
# [Step=150]	Loss=2.3223	acc=0.3839	4690.8 examples/second
# Test Loss=2.2477, Test acc=0.4093
#
# Epoch: 18
# [Step=50]	Loss=2.3072	acc=0.3878	3749.3 examples/second
# [Step=100]	Loss=2.3161	acc=0.3860	4544.4 examples/second
# [Step=150]	Loss=2.3164	acc=0.3875	4459.5 examples/second
# Test Loss=2.2165, Test acc=0.4124
#
# Epoch: 19
# [Step=50]	Loss=2.2929	acc=0.4007	4041.1 examples/second
# [Step=100]	Loss=2.3128	acc=0.3946	4733.1 examples/second
# [Step=150]	Loss=2.3176	acc=0.3938	4596.1 examples/second
# Test Loss=2.2064, Test acc=0.4108

# %%
net.load_state_dict(torch.load("quantized_net_after_global_iterative_prune.pt"))

zeros_sum = 0
total_sum = 0
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        np_weight = layer.weight.data.cpu().numpy()
        zeros = (np_weight==0).sum()
        total = np_weight.flatten().shape[0]
        zeros_sum+=zeros
        total_sum+=total
        print('Sparsity of '+name+': '+str(zeros/total))
print('Total sparsity of: '+str(zeros_sum/total_sum))
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.30787037037037035
# Sparsity of body_op.0.conv1.0.conv: 0.6575520833333334
# Sparsity of body_op.0.conv2.0.conv: 0.6397569444444444
# Sparsity of body_op.1.conv1.0.conv: 0.6280381944444444
# Sparsity of body_op.1.conv2.0.conv: 0.6488715277777778
# Sparsity of body_op.2.conv1.0.conv: 0.6315104166666666
# Sparsity of body_op.2.conv2.0.conv: 0.6684027777777778
# Sparsity of body_op.3.conv1.0.conv: 0.6252170138888888
# Sparsity of body_op.3.conv2.0.conv: 0.6882595486111112
# Sparsity of body_op.4.conv1.0.conv: 0.7261284722222222
# Sparsity of body_op.4.conv2.0.conv: 0.7820095486111112
# Sparsity of body_op.5.conv1.0.conv: 0.7249348958333334
# Sparsity of body_op.5.conv2.0.conv: 0.8132595486111112
# Sparsity of body_op.6.conv1.0.conv: 0.7331814236111112
# Sparsity of body_op.6.conv2.0.conv: 0.7640245225694444
# Sparsity of body_op.7.conv1.0.conv: 0.7770453559027778
# Sparsity of body_op.7.conv2.0.conv: 0.8261176215277778
# Sparsity of body_op.8.conv1.0.conv: 0.8527018229166666
# Sparsity of body_op.8.conv2.0.conv: 0.9764539930555556
# Sparsity of final_fc.linear: 0.159375
# Total sparsity of: 0.7999970186631685
# Files already downloaded and verified
# Test Loss=2.2337, Test accuracy=0.4125

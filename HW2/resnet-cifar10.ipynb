# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
def SwishActivation(x):
    return x / (1 + torch.exp(-x))

# %%
class FeatureMapSpecificLayer(nn.Module):
    
    def __init__(self,in_channels, filters, kernel_size, stride, padding):
        super(FeatureMapSpecificLayer, self).__init__()
        
        self.stride = stride
        self.conv1 = nn.Conv2d(in_channels = in_channels, out_channels = filters,
                               kernel_size = kernel_size, stride = stride, padding = padding)
        self.bn1 = nn.BatchNorm2d(filters)
        
        self.conv2 = nn.Conv2d(in_channels = filters, out_channels = filters,
                               kernel_size = kernel_size, stride = 1, padding = padding)
        self.bn2 = nn.BatchNorm2d(filters)
        
        self.shortcut1 = nn.Conv2d(in_channels = in_channels, out_channels = filters,
                               kernel_size = 1, stride = stride, padding = 0)
        self.bn3 = nn.BatchNorm2d(filters)
        
        
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        
        if self.stride != 1:
            shortcut = self.bn3(self.shortcut1(x))
        else:
            shortcut = x
                        
        out = F.relu(out + shortcut)
        return out

# %%
class LayerStack(nn.Module):
    
    def __init__(self,in_channels, filters, kernel_size, stride, padding):
        super(LayerStack, self).__init__()
        
        self.fmap_layer1 = FeatureMapSpecificLayer(in_channels = in_channels,
                                                   filters = filters, 
                                                   kernel_size = kernel_size, 
                                                   stride = stride, padding = padding)
        
        self.fmap_layer2 = FeatureMapSpecificLayer(in_channels = filters,
                                                   filters = filters,
                                                   kernel_size = kernel_size, 
                                                   stride = 1, padding = padding)
        
        self.fmap_layer3 = FeatureMapSpecificLayer(in_channels = filters,
                                                   filters = filters,
                                                   kernel_size = kernel_size, 
                                                   stride = 1, padding = padding)
    
    def forward(self,x):
        out = self.fmap_layer1(x)
        out = self.fmap_layer2(out)
        out = self.fmap_layer3(out)
        return out

# %%
# define the SimpleNN mode;
class ResNet20(nn.Module):
    def __init__(self):
        super(ResNet20, self).__init__()
        
        p = 1
        
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 16,
                               kernel_size = 3, stride = 1, padding = p)
        self.bn1 = nn.BatchNorm2d(16)
                
        self.layer1 = LayerStack(in_channels = 16, filters = 16, 
                                  kernel_size = 3, stride = 1, padding = p)
                
        self.layer2 = LayerStack(in_channels = 16, filters = 32, 
                                  kernel_size = 3, stride = 2, padding = p)
                
        self.layer3 = LayerStack(in_channels = 32, filters = 64, 
                                  kernel_size = 3, stride = 2, padding = p)
        
        self.pooling = nn.AvgPool2d(8)
                
        self.fc1   = nn.Linear(in_features = 64,
                               out_features = 10)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.pooling(out)

        out = self.fc1(torch.reshape(out,(out.size(0),-1)))
        return out

# %% [markdown]
# ### Question (a)
# Here is a sanity check to verify the implementation of SimpleNN.
# You need to:
# 1. Write down your code.
# 2. **In the PDF report**, give a brief description on how the code helps you know that SimpleNN is implemented correctly.

# %%
#############################################
# your code here
# sanity check for the correctness of SimpleNN

# GPU check                
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")

# Model Definition  
net = ResNet20()
net = net.to(device)

# Test forward pass
data = torch.randn(5,3,32,32)
data = data.to(device)
# Forward pass "data" through "net" to get output "out" 
out = net.forward(data)    #Your code here

print(out.detach().cpu().numpy().shape)

# Check output shape
assert(out.detach().cpu().numpy().shape == (5,10))
print("Forward pass successful")


#############################################
# Out:
# Run on GPU...
# (5, 10)
# Forward pass successful

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
mean_images = [0.4914, 0.4822, 0.4465]
std_images = [0.2023, 0.1994, 0.2010]

#transforms.RandomCrop(size=(3,32,32), padding = 2)
#transforms.RandomHorizontalFlip()
#transforms.RandomVerticalFlip()

transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(size=(32,32), padding = 4),
    transforms.Normalize(mean=mean_images, std=std_images)
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=mean_images, std=std_images)
])
#############################################

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
# do NOT change these
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform= transform_train    # your code
)
val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform= transform_val    # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size= TRAIN_BATCH_SIZE,  # your code
    shuffle=True,     # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set, 
    batch_size= VAL_BATCH_SIZE,  # your code
    shuffle=False,     # your code
    num_workers=4
)
#############################################
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here

# GPU check                
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")

# Model Definition  
net = ResNet20()
#state_dict = torch.load('./saved_model/resnet20.pth')
#net.load_state_dict(state_dict['state_dict'])
net = net.to(device)
    
#############################################
# Out:
# Run on GPU...

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-4

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=INITIAL_LR, momentum = MOMENTUM, weight_decay = REG)
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities?)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 200
DECAY_EPOCHS = 40
DECAY = 0.1

# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    # handle the learning rate scheduler.
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    #######################
    # your code here
    # switch to train mode
    
    net.train()
    
    #######################
    
    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0
    
    if i % 20 == 0:
        print("Saving ...")
        state = {'state_dict': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'resnet20_20threshold.pth'))

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs, targets = inputs.to(device), targets.to(device)
        
        # compute the output and loss
        y_pred = net(inputs)
        loss = criterion(y_pred, targets)
        train_loss += loss
        
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        #correct_current_batch = 0
        #for target, pred in zip(targets, y_pred):
        #    if target == torch.argmax(pred):
        #        correct_current_batch+=1
        correct_current_batch = (targets-torch.argmax(y_pred, axis=1) == 0).sum().item()
        
        correct_examples += correct_current_batch
        total_examples += len(targets)
        
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    
    net.eval()
    
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs, targets = inputs.to(device), targets.to(device)
            
            # compute the output and loss
            y_pred = net(inputs)
            loss = criterion(y_pred, targets)
            val_loss += loss
            
            # count the number of correctly predicted samples in the current batch
            #correct_current_batch=0
            #for target, pred in zip(targets, y_pred):
                #if target == torch.argmax(pred):
                    #correct_current_batch+=1
                
            correct_current_batch = (targets-torch.argmax(y_pred, axis=1) == 0).sum().item()

            correct_examples += correct_current_batch
            total_examples += len(targets)
            
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'resnet20.pth'))
        
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Saving ...
# Training loss: 1.7162, Training accuracy: 0.3549
# Validation loss: 1.3874, Validation accuracy: 0.4970
# Saving ...
#
# Epoch 1:
# Training loss: 1.1559, Training accuracy: 0.5841
# Validation loss: 1.3093, Validation accuracy: 0.5604
# Saving ...
#
# Epoch 2:
# Training loss: 0.8885, Training accuracy: 0.6853
# Validation loss: 0.9254, Validation accuracy: 0.6798
# Saving ...
#
# Epoch 3:
# Training loss: 0.7475, Training accuracy: 0.7390
# Validation loss: 0.8447, Validation accuracy: 0.7176
# Saving ...
#
# Epoch 4:
# Training loss: 0.6587, Training accuracy: 0.7730
# Validation loss: 0.6784, Validation accuracy: 0.7684
# Saving ...
#
# Epoch 5:
# Training loss: 0.6014, Training accuracy: 0.7921
# Validation loss: 0.6330, Validation accuracy: 0.7840
# Saving ...
#
# Epoch 6:
# Training loss: 0.5597, Training accuracy: 0.8059
# Validation loss: 0.6488, Validation accuracy: 0.7808
#
# Epoch 7:
# Training loss: 0.5205, Training accuracy: 0.8213
# Validation loss: 0.5759, Validation accuracy: 0.8088
#
# Epoch 132:
# Training loss: 0.0222, Training accuracy: 0.9937
# Validation loss: 0.4049, Validation accuracy: 0.9052
#
# Epoch 133:
# Training loss: 0.0219, Training accuracy: 0.9943
# Validation loss: 0.4069, Validation accuracy: 0.9054
#
# Epoch 134:
# Training loss: 0.0228, Training accuracy: 0.9941
# Validation loss: 0.4070, Validation accuracy: 0.9050
#
# Epoch 135:
# Training loss: 0.0223, Training accuracy: 0.9937
# Validation loss: 0.4055, Validation accuracy: 0.9058
#
# Epoch 136:
# Training loss: 0.0213, Training accuracy: 0.9943
# Validation loss: 0.4122, Validation accuracy: 0.9020
#
# Epoch 137:
# Training loss: 0.0222, Training accuracy: 0.9937
# Validation loss: 0.4106, Validation accuracy: 0.9040
#
# Epoch 138:
# Training loss: 0.0215, Training accuracy: 0.9942
# Validation loss: 0.4093, Validation accuracy: 0.9038
#
# Epoch 139:
# Training loss: 0.0219, Training accuracy: 0.9939
# Validation loss: 0.4077, Validation accuracy: 0.9064
#
# Epoch 140:
# Saving ...
# Training loss: 0.0214, Training accuracy: 0.9948
# Validation loss: 0.4093, Validation accuracy: 0.9034
#
# Epoch 141:
# Training loss: 0.0211, Training accuracy: 0.9942
# Validation loss: 0.4066, Validation accuracy: 0.9062
#
# Epoch 142:
# Training loss: 0.0216, Training accuracy: 0.9939
# Validation loss: 0.4048, Validation accuracy: 0.9042
#
# Epoch 143:
# Training loss: 0.0209, Training accuracy: 0.9943
# Validation loss: 0.4079, Validation accuracy: 0.9048
#
# Epoch 144:
# Training loss: 0.0210, Training accuracy: 0.9946
# Validation loss: 0.4063, Validation accuracy: 0.9070
#
# Epoch 145:
# Training loss: 0.0218, Training accuracy: 0.9940
# Validation loss: 0.4099, Validation accuracy: 0.9074
#
# Epoch 146:
# Training loss: 0.0230, Training accuracy: 0.9936
# Validation loss: 0.4120, Validation accuracy: 0.9038
#
# Epoch 147:
# Training loss: 0.0218, Training accuracy: 0.9941
# Validation loss: 0.4054, Validation accuracy: 0.9060
#
# Epoch 148:
# Training loss: 0.0222, Training accuracy: 0.9940
# Validation loss: 0.4102, Validation accuracy: 0.9042
#
# Epoch 149:
# Training loss: 0.0220, Training accuracy: 0.9936
# Validation loss: 0.4076, Validation accuracy: 0.9032
#
# Epoch 150:
# Training loss: 0.0208, Training accuracy: 0.9946
# Validation loss: 0.4074, Validation accuracy: 0.9052
#
# Epoch 151:
# Training loss: 0.0212, Training accuracy: 0.9941
# Validation loss: 0.4059, Validation accuracy: 0.9052
#
# Epoch 152:
# Training loss: 0.0221, Training accuracy: 0.9940
# Validation loss: 0.4055, Validation accuracy: 0.9056
#
# Epoch 153:
# Training loss: 0.0213, Training accuracy: 0.9942
# Validation loss: 0.4035, Validation accuracy: 0.9062
#
# Epoch 154:

# %% [markdown]
# # Bonus: with learning rate decay
#
# The following code can help you adjust the learning rate during training. You need to figure out how to incorporate this code into your training loop.
# ```python
#     if i % DECAY_EPOCHS == 0 and i != 0:
#         current_learning_rate = current_learning_rate * DECAY
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = current_learning_rate
#         print("Current learning rate has decayed to %f" %current_learning_rate)
# ```
